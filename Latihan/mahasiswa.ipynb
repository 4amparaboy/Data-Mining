# %%
import pandas as pd

# %%
df = pd.read_csv("./data_mahasiswa.csv")
df = df.loc[:, df.columns!='id']
df = df.iloc[:15] # Membaca 15 data pertama

# %%
df.plot.scatter(y="name", x="ipk")
# Out:
# <Axes: xlabel='ipk', ylabel='name'>
